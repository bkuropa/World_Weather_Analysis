# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from citipy import citipy

import time
from datetime import datetime
# Out:
# In C:\Users\bkuro\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\bkuro\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\bkuro\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In C:\Users\bkuro\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\bkuro\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The savefig.jpeg_quality rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\bkuro\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The keymap.all_axes rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\bkuro\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_path rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In C:\Users\bkuro\Anaconda3\lib\site-packages\matplotlib\mpl-data\stylelib\_classic_test.mplstyle:
# The animation.avconv_args rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.

# %%
import requests
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Kelvin"
#city = "toronto"

# %% [markdown]
# query_url = url + "appid=" + weather_api_key + "&q=" + city
# weather_response = requests.get(query_url)
# weather_json = weather_response.json()
# weather_json.get("weather")

# %%
# Create a set of random latitude and longitude coordinates.
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    #city_url = url + "&q=" + city.replace(" ","+")
    city_url = url + "&APPID=" + weather_api_key + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    
    #city_weather = requests.get(city_url).json()
    
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_desc,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sistranda
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | east london
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | vardo
# Processing Record 8 of Set 1 | hobart
# Processing Record 9 of Set 1 | pochutla
# Processing Record 10 of Set 1 | upernavik
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | hermanus
# Processing Record 13 of Set 1 | le port
# Processing Record 14 of Set 1 | ilulissat
# Processing Record 15 of Set 1 | castro
# Processing Record 16 of Set 1 | butaritari
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | northam
# Processing Record 19 of Set 1 | kavieng
# Processing Record 20 of Set 1 | tautira
# Processing Record 21 of Set 1 | tongliao
# Processing Record 22 of Set 1 | yanam
# Processing Record 23 of Set 1 | kodiak
# Processing Record 24 of Set 1 | mutis
# Processing Record 25 of Set 1 | ponta do sol
# Processing Record 26 of Set 1 | sibiti
# Processing Record 27 of Set 1 | mahebourg
# Processing Record 28 of Set 1 | norman wells
# Processing Record 29 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | katsuura
# Processing Record 32 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 33 of Set 1 | souillac
# Processing Record 34 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 1 | provideniya
# Processing Record 36 of Set 1 | kolyshley
# Processing Record 37 of Set 1 | hay river
# Processing Record 38 of Set 1 | pimentel
# Processing Record 39 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 40 of Set 1 | chuy
# Processing Record 41 of Set 1 | westpunt
# City not found. Skipping...
# Processing Record 42 of Set 1 | kaitangata
# Processing Record 43 of Set 1 | hasaki
# Processing Record 44 of Set 1 | lebu
# Processing Record 45 of Set 1 | yulara
# Processing Record 46 of Set 1 | arraial do cabo
# Processing Record 47 of Set 1 | lakhna
# Processing Record 48 of Set 1 | hudiksvall
# Processing Record 49 of Set 1 | salym
# Processing Record 50 of Set 1 | cherskiy
# Processing Record 1 of Set 2 | adana
# Processing Record 2 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 2 | kahului
# Processing Record 4 of Set 2 | bluff
# Processing Record 5 of Set 2 | roxana
# Processing Record 6 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 2 | thompson
# Processing Record 8 of Set 2 | hithadhoo
# Processing Record 9 of Set 2 | pisco
# Processing Record 10 of Set 2 | bundaberg
# Processing Record 11 of Set 2 | cayenne
# Processing Record 12 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 2 | mar del plata
# Processing Record 14 of Set 2 | ebolowa
# Processing Record 15 of Set 2 | coahuayana
# Processing Record 16 of Set 2 | dikson
# Processing Record 17 of Set 2 | albany
# Processing Record 18 of Set 2 | port-de-paix
# City not found. Skipping...
# Processing Record 19 of Set 2 | burnie
# Processing Record 20 of Set 2 | bredasdorp
# Processing Record 21 of Set 2 | airai
# Processing Record 22 of Set 2 | dandong
# Processing Record 23 of Set 2 | ribeira grande
# Processing Record 24 of Set 2 | labuhan
# Processing Record 25 of Set 2 | holt
# Processing Record 26 of Set 2 | dalhousie
# Processing Record 27 of Set 2 | kathmandu
# Processing Record 28 of Set 2 | lompoc
# Processing Record 29 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 30 of Set 2 | pangai
# Processing Record 31 of Set 2 | port alfred
# Processing Record 32 of Set 2 | nichinan
# Processing Record 33 of Set 2 | port blair
# Processing Record 34 of Set 2 | sandpoint
# Processing Record 35 of Set 2 | puerto ayora
# Processing Record 36 of Set 2 | korla
# Processing Record 37 of Set 2 | bilibino
# Processing Record 38 of Set 2 | nalut
# Processing Record 39 of Set 2 | oga
# Processing Record 40 of Set 2 | avarua
# Processing Record 41 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 2 | margate
# Processing Record 43 of Set 2 | hilo
# Processing Record 44 of Set 2 | caravelas
# Processing Record 45 of Set 2 | yakeshi
# Processing Record 46 of Set 2 | mapiripan
# Processing Record 47 of Set 2 | ambovombe
# Processing Record 48 of Set 2 | vila velha
# Processing Record 49 of Set 2 | luderitz
# Processing Record 50 of Set 2 | alofi
# Processing Record 1 of Set 3 | ust-tsilma
# Processing Record 2 of Set 3 | ulladulla
# Processing Record 3 of Set 3 | ushibuka
# Processing Record 4 of Set 3 | shirokiy
# Processing Record 5 of Set 3 | perelyub
# Processing Record 6 of Set 3 | osakarovka
# Processing Record 7 of Set 3 | bethel
# Processing Record 8 of Set 3 | baoro
# Processing Record 9 of Set 3 | waterloo
# Processing Record 10 of Set 3 | namatanai
# Processing Record 11 of Set 3 | marsh harbour
# Processing Record 12 of Set 3 | hamilton
# Processing Record 13 of Set 3 | linxia
# Processing Record 14 of Set 3 | moratuwa
# Processing Record 15 of Set 3 | zhezkazgan
# Processing Record 16 of Set 3 | qaanaaq
# Processing Record 17 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 3 | carutapera
# Processing Record 19 of Set 3 | jamestown
# Processing Record 20 of Set 3 | mukhen
# Processing Record 21 of Set 3 | punta arenas
# Processing Record 22 of Set 3 | gerash
# Processing Record 23 of Set 3 | sabang
# Processing Record 24 of Set 3 | kholmogory
# Processing Record 25 of Set 3 | hauterive
# Processing Record 26 of Set 3 | saint-philippe
# Processing Record 27 of Set 3 | port hedland
# Processing Record 28 of Set 3 | kruisfontein
# Processing Record 29 of Set 3 | mount isa
# Processing Record 30 of Set 3 | marsa matruh
# Processing Record 31 of Set 3 | kalmunai
# Processing Record 32 of Set 3 | san patricio
# Processing Record 33 of Set 3 | yellowknife
# Processing Record 34 of Set 3 | peniche
# Processing Record 35 of Set 3 | bonavista
# Processing Record 36 of Set 3 | new norfolk
# Processing Record 37 of Set 3 | vicuna
# Processing Record 38 of Set 3 | nemuro
# Processing Record 39 of Set 3 | cedar city
# Processing Record 40 of Set 3 | gornopravdinsk
# Processing Record 41 of Set 3 | ishinomaki
# Processing Record 42 of Set 3 | saint-augustin
# Processing Record 43 of Set 3 | jutai
# Processing Record 44 of Set 3 | sao francisco de assis
# Processing Record 45 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 3 | namibe
# Processing Record 47 of Set 3 | faanui
# Processing Record 48 of Set 3 | victoria
# Processing Record 49 of Set 3 | raga
# Processing Record 50 of Set 3 | cape town
# Processing Record 1 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 2 of Set 4 | pevek
# Processing Record 3 of Set 4 | chokurdakh
# Processing Record 4 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 5 of Set 4 | hualmay
# Processing Record 6 of Set 4 | kem
# Processing Record 7 of Set 4 | lavrentiya
# Processing Record 8 of Set 4 | port augusta
# Processing Record 9 of Set 4 | moindou
# Processing Record 10 of Set 4 | port elizabeth
# Processing Record 11 of Set 4 | bolshoye selo
# Processing Record 12 of Set 4 | talnakh
# Processing Record 13 of Set 4 | severo-kurilsk
# Processing Record 14 of Set 4 | benghazi
# Processing Record 15 of Set 4 | zheleznodorozhnyy
# Processing Record 16 of Set 4 | yangjiang
# Processing Record 17 of Set 4 | bystryy istok
# Processing Record 18 of Set 4 | geraldton
# Processing Record 19 of Set 4 | egvekinot
# Processing Record 20 of Set 4 | smoky lake
# Processing Record 21 of Set 4 | tafresh
# Processing Record 22 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 4 | torbay
# Processing Record 24 of Set 4 | verkhnyaya inta
# Processing Record 25 of Set 4 | angoche
# Processing Record 26 of Set 4 | huallanca
# Processing Record 27 of Set 4 | balila
# Processing Record 28 of Set 4 | la ronge
# Processing Record 29 of Set 4 | acapulco
# Processing Record 30 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 4 | longyearbyen
# Processing Record 32 of Set 4 | lorengau
# Processing Record 33 of Set 4 | shetpe
# Processing Record 34 of Set 4 | palmer
# Processing Record 35 of Set 4 | georgetown
# Processing Record 36 of Set 4 | broken hill
# Processing Record 37 of Set 4 | lakatoro
# Processing Record 38 of Set 4 | ust-omchug
# Processing Record 39 of Set 4 | klaksvik
# Processing Record 40 of Set 4 | holme
# Processing Record 41 of Set 4 | salalah
# Processing Record 42 of Set 4 | juneau
# Processing Record 43 of Set 4 | tasiilaq
# Processing Record 44 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 45 of Set 4 | general pico
# Processing Record 46 of Set 4 | krasnoselkup
# Processing Record 47 of Set 4 | te anau
# Processing Record 48 of Set 4 | kabare
# Processing Record 49 of Set 4 | nyurba
# Processing Record 50 of Set 4 | zirgan
# Processing Record 1 of Set 5 | umm lajj
# Processing Record 2 of Set 5 | holstebro
# Processing Record 3 of Set 5 | ewa beach
# Processing Record 4 of Set 5 | laguna
# Processing Record 5 of Set 5 | nikolskoye
# Processing Record 6 of Set 5 | gobabis
# Processing Record 7 of Set 5 | hofn
# Processing Record 8 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 9 of Set 5 | bengkulu
# Processing Record 10 of Set 5 | tiksi
# Processing Record 11 of Set 5 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 12 of Set 5 | ostrovnoy
# Processing Record 13 of Set 5 | tignere
# Processing Record 14 of Set 5 | roma
# Processing Record 15 of Set 5 | maceio
# Processing Record 16 of Set 5 | east millcreek
# Processing Record 17 of Set 5 | itum-kale
# Processing Record 18 of Set 5 | quchan
# Processing Record 19 of Set 5 | aklavik
# Processing Record 20 of Set 5 | mersing
# Processing Record 21 of Set 5 | lagoa
# Processing Record 22 of Set 5 | alta
# Processing Record 23 of Set 5 | parakai
# Processing Record 24 of Set 5 | ha tinh
# Processing Record 25 of Set 5 | forest grove
# Processing Record 26 of Set 5 | zhuanghe
# Processing Record 27 of Set 5 | marawi
# Processing Record 28 of Set 5 | san ramon de la nueva oran
# Processing Record 29 of Set 5 | okhotsk
# Processing Record 30 of Set 5 | mercedes
# Processing Record 31 of Set 5 | sao filipe
# Processing Record 32 of Set 5 | castro marim
# Processing Record 33 of Set 5 | newala
# Processing Record 34 of Set 5 | barrow
# Processing Record 35 of Set 5 | abonnema
# Processing Record 36 of Set 5 | pacific grove
# Processing Record 37 of Set 5 | isangel
# Processing Record 38 of Set 5 | okha
# Processing Record 39 of Set 5 | falticeni
# Processing Record 40 of Set 5 | itanagar
# Processing Record 41 of Set 5 | otjimbingwe
# Processing Record 42 of Set 5 | baherden
# Processing Record 43 of Set 5 | skala
# Processing Record 44 of Set 5 | yeppoon
# Processing Record 45 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 46 of Set 5 | zverinogolovskoye
# Processing Record 47 of Set 5 | bathsheba
# Processing Record 48 of Set 5 | kavaratti
# Processing Record 49 of Set 5 | juarez
# Processing Record 50 of Set 5 | gejiu
# Processing Record 1 of Set 6 | saldanha
# Processing Record 2 of Set 6 | mergui
# City not found. Skipping...
# Processing Record 3 of Set 6 | leningradskiy
# Processing Record 4 of Set 6 | makokou
# Processing Record 5 of Set 6 | ahipara
# Processing Record 6 of Set 6 | tarauaca
# Processing Record 7 of Set 6 | clyde river
# Processing Record 8 of Set 6 | touros
# Processing Record 9 of Set 6 | gorzow wielkopolski
# Processing Record 10 of Set 6 | gympie
# Processing Record 11 of Set 6 | chifeng
# Processing Record 12 of Set 6 | kargasok
# Processing Record 13 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 14 of Set 6 | roswell
# Processing Record 15 of Set 6 | jardim
# Processing Record 16 of Set 6 | baoding
# Processing Record 17 of Set 6 | umea
# Processing Record 18 of Set 6 | bonthe
# Processing Record 19 of Set 6 | gat
# Processing Record 20 of Set 6 | beira
# Processing Record 21 of Set 6 | naze
# Processing Record 22 of Set 6 | ndioum
# Processing Record 23 of Set 6 | comodoro rivadavia
# Processing Record 24 of Set 6 | dillon
# Processing Record 25 of Set 6 | soavinandriana
# Processing Record 26 of Set 6 | ranau
# Processing Record 27 of Set 6 | carauari
# Processing Record 28 of Set 6 | pandan
# Processing Record 29 of Set 6 | raikot
# Processing Record 30 of Set 6 | sorland
# Processing Record 31 of Set 6 | carnarvon
# Processing Record 32 of Set 6 | omboue
# Processing Record 33 of Set 6 | vaini
# Processing Record 34 of Set 6 | birjand
# Processing Record 35 of Set 6 | bikaner
# Processing Record 36 of Set 6 | cockburn town
# Processing Record 37 of Set 6 | verkhnyaya toyma
# Processing Record 38 of Set 6 | wajir
# Processing Record 39 of Set 6 | svobodnyy
# Processing Record 40 of Set 6 | hobyo
# Processing Record 41 of Set 6 | mount gambier
# Processing Record 42 of Set 6 | mancio lima
# Processing Record 43 of Set 6 | vryburg
# Processing Record 44 of Set 6 | nanortalik
# Processing Record 45 of Set 6 | portland
# Processing Record 46 of Set 6 | hamada
# Processing Record 47 of Set 6 | dingle
# Processing Record 48 of Set 6 | harwich
# Processing Record 49 of Set 6 | abu zabad
# Processing Record 50 of Set 6 | kenora
# Processing Record 1 of Set 7 | muisne
# Processing Record 2 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 7 | berlevag
# Processing Record 4 of Set 7 | grao mogol
# Processing Record 5 of Set 7 | rundu
# Processing Record 6 of Set 7 | tuatapere
# Processing Record 7 of Set 7 | beyneu
# Processing Record 8 of Set 7 | dongsheng
# Processing Record 9 of Set 7 | lagdo
# Processing Record 10 of Set 7 | bantry
# Processing Record 11 of Set 7 | qostanay
# Processing Record 12 of Set 7 | xuanhua
# Processing Record 13 of Set 7 | amapa
# Processing Record 14 of Set 7 | sitka
# Processing Record 15 of Set 7 | pangnirtung
# Processing Record 16 of Set 7 | saskylakh
# Processing Record 17 of Set 7 | tshela
# Processing Record 18 of Set 7 | flinders
# Processing Record 19 of Set 7 | sobreira
# Processing Record 20 of Set 7 | hami
# Processing Record 21 of Set 7 | kununurra
# Processing Record 22 of Set 7 | uroteppa
# City not found. Skipping...
# Processing Record 23 of Set 7 | kaeo
# Processing Record 24 of Set 7 | tungkang
# City not found. Skipping...
# Processing Record 25 of Set 7 | bulawayo
# Processing Record 26 of Set 7 | meulaboh
# Processing Record 27 of Set 7 | tank
# Processing Record 28 of Set 7 | plettenberg bay
# Processing Record 29 of Set 7 | swan hill
# Processing Record 30 of Set 7 | nizhnevartovsk
# Processing Record 31 of Set 7 | rudbar
# Processing Record 32 of Set 7 | port hardy
# Processing Record 33 of Set 7 | calvia
# Processing Record 34 of Set 7 | dabola
# Processing Record 35 of Set 7 | vestmannaeyjar
# Processing Record 36 of Set 7 | mixtepec
# City not found. Skipping...
# Processing Record 37 of Set 7 | pirgos
# Processing Record 38 of Set 7 | yinchuan
# Processing Record 39 of Set 7 | jabiru
# City not found. Skipping...
# Processing Record 40 of Set 7 | blagodatnoye
# Processing Record 41 of Set 7 | tabou
# Processing Record 42 of Set 7 | fallon
# Processing Record 43 of Set 7 | gravdal
# Processing Record 44 of Set 7 | tuktoyaktuk
# Processing Record 45 of Set 7 | maltahohe
# Processing Record 46 of Set 7 | karakendzha
# City not found. Skipping...
# Processing Record 47 of Set 7 | opunake
# Processing Record 48 of Set 7 | axim
# Processing Record 49 of Set 7 | duminichi
# Processing Record 50 of Set 7 | khuzhir
# Processing Record 1 of Set 8 | bambous virieux
# Processing Record 2 of Set 8 | billings
# Processing Record 3 of Set 8 | matadi
# Processing Record 4 of Set 8 | ancud
# Processing Record 5 of Set 8 | constitucion
# Processing Record 6 of Set 8 | kultuk
# Processing Record 7 of Set 8 | islamkot
# Processing Record 8 of Set 8 | makakilo city
# Processing Record 9 of Set 8 | cabo san lucas
# Processing Record 10 of Set 8 | eirunepe
# Processing Record 11 of Set 8 | ensley
# Processing Record 12 of Set 8 | ayan
# Processing Record 13 of Set 8 | porto santo
# Processing Record 14 of Set 8 | marovoay
# Processing Record 15 of Set 8 | husavik
# Processing Record 16 of Set 8 | yumen
# Processing Record 17 of Set 8 | yarovoye
# Processing Record 18 of Set 8 | ytre arna
# Processing Record 19 of Set 8 | milkovo
# Processing Record 20 of Set 8 | khrisokastron
# City not found. Skipping...
# Processing Record 21 of Set 8 | walvis bay
# Processing Record 22 of Set 8 | kutum
# Processing Record 23 of Set 8 | devonport
# Processing Record 24 of Set 8 | kuryk
# Processing Record 25 of Set 8 | hanting
# Processing Record 26 of Set 8 | paamiut
# Processing Record 27 of Set 8 | sambava
# Processing Record 28 of Set 8 | gaspe
# Processing Record 29 of Set 8 | codrington
# Processing Record 30 of Set 8 | dasoguz
# Processing Record 31 of Set 8 | katherine
# Processing Record 32 of Set 8 | dunedin
# Processing Record 33 of Set 8 | road town
# Processing Record 34 of Set 8 | huarmey
# Processing Record 35 of Set 8 | yurya
# City not found. Skipping...
# Processing Record 36 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 8 | bojaya
# City not found. Skipping...
# Processing Record 38 of Set 8 | aykhal
# Processing Record 39 of Set 8 | mugur-aksy
# Processing Record 40 of Set 8 | kharp
# Processing Record 41 of Set 8 | casper
# Processing Record 42 of Set 8 | high level
# Processing Record 43 of Set 8 | lesosibirsk
# Processing Record 44 of Set 8 | broome
# Processing Record 45 of Set 8 | tveit
# Processing Record 46 of Set 8 | uri
# Processing Record 47 of Set 8 | belyy yar
# Processing Record 48 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 8 | ngaoundere
# Processing Record 50 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 1 of Set 9 | ituni
# City not found. Skipping...
# Processing Record 2 of Set 9 | qasigiannguit
# Processing Record 3 of Set 9 | auki
# Processing Record 4 of Set 9 | beringovskiy
# Processing Record 5 of Set 9 | sao joao da barra
# Processing Record 6 of Set 9 | saint george
# Processing Record 7 of Set 9 | siilinjarvi
# Processing Record 8 of Set 9 | loukhi
# Processing Record 9 of Set 9 | hoopstad
# Processing Record 10 of Set 9 | mehriz
# Processing Record 11 of Set 9 | marienburg
# Processing Record 12 of Set 9 | victoria point
# Processing Record 13 of Set 9 | maningrida
# Processing Record 14 of Set 9 | oktyabrskoye
# Processing Record 15 of Set 9 | morondava
# Processing Record 16 of Set 9 | emerald
# Processing Record 17 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 19 of Set 9 | kilakarai
# Processing Record 20 of Set 9 | yasnyy
# Processing Record 21 of Set 9 | jiblah
# Processing Record 22 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 23 of Set 9 | kalga
# Processing Record 24 of Set 9 | zlatoustovsk
# City not found. Skipping...
# Processing Record 25 of Set 9 | praia
# Processing Record 26 of Set 9 | springbok
# Processing Record 27 of Set 9 | kumla
# Processing Record 28 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 29 of Set 9 | rayachoti
# Processing Record 30 of Set 9 | gornouralskiy
# City not found. Skipping...
# Processing Record 31 of Set 9 | basyanovskiy
# City not found. Skipping...
# Processing Record 32 of Set 9 | esil
# Processing Record 33 of Set 9 | yar-sale
# Processing Record 34 of Set 9 | tessalit
# Processing Record 35 of Set 9 | eureka
# Processing Record 36 of Set 9 | neiafu
# Processing Record 37 of Set 9 | sabha
# Processing Record 38 of Set 9 | daru
# Processing Record 39 of Set 9 | golden
# Processing Record 40 of Set 9 | wum
# Processing Record 41 of Set 9 | iqaluit
# Processing Record 42 of Set 9 | nilanga
# Processing Record 43 of Set 9 | kankon
# Processing Record 44 of Set 9 | poltavka
# Processing Record 45 of Set 9 | lazaro cardenas
# Processing Record 46 of Set 9 | lata
# Processing Record 47 of Set 9 | salinas
# Processing Record 48 of Set 9 | khatanga
# Processing Record 49 of Set 9 | vilhena
# Processing Record 50 of Set 9 | urubamba
# Processing Record 1 of Set 10 | fortuna
# Processing Record 2 of Set 10 | victor harbor
# Processing Record 3 of Set 10 | agirish
# Processing Record 4 of Set 10 | maragogi
# Processing Record 5 of Set 10 | seydi
# Processing Record 6 of Set 10 | prince rupert
# Processing Record 7 of Set 10 | dhidhdhoo
# Processing Record 8 of Set 10 | russell
# Processing Record 9 of Set 10 | vestmanna
# Processing Record 10 of Set 10 | yamoussoukro
# Processing Record 11 of Set 10 | asmar
# Processing Record 12 of Set 10 | valparaiso
# Processing Record 13 of Set 10 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 10 | port lincoln
# Processing Record 15 of Set 10 | melilla
# Processing Record 16 of Set 10 | palu
# Processing Record 17 of Set 10 | stryn
# Processing Record 18 of Set 10 | kapoeta
# Processing Record 19 of Set 10 | saint-francois
# Processing Record 20 of Set 10 | el vigia
# Processing Record 21 of Set 10 | ketchikan
# Processing Record 22 of Set 10 | aban
# Processing Record 23 of Set 10 | anar darreh
# City not found. Skipping...
# Processing Record 24 of Set 10 | trairi
# Processing Record 25 of Set 10 | matagami
# Processing Record 26 of Set 10 | iracoubo
# Processing Record 27 of Set 10 | pinheiro machado
# Processing Record 28 of Set 10 | acajutla
# Processing Record 29 of Set 10 | nizamabad
# Processing Record 30 of Set 10 | lagos
# Processing Record 31 of Set 10 | san quintin
# Processing Record 32 of Set 10 | tolstoy-yurt
# Processing Record 33 of Set 10 | a
# City not found. Skipping...
# Processing Record 34 of Set 10 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 35 of Set 10 | kolondieba
# Processing Record 36 of Set 10 | kulhudhuffushi
# Processing Record 37 of Set 10 | irbeyskoye
# Processing Record 38 of Set 10 | vila franca do campo
# Processing Record 39 of Set 10 | perivolion
# Processing Record 40 of Set 10 | maniitsoq
# Processing Record 41 of Set 10 | poum
# Processing Record 42 of Set 10 | ocala
# Processing Record 43 of Set 10 | macamic
# Processing Record 44 of Set 10 | cap malheureux
# Processing Record 45 of Set 10 | deputatskiy
# Processing Record 46 of Set 10 | hannibal
# Processing Record 47 of Set 10 | tipitapa
# Processing Record 48 of Set 10 | bintulu
# Processing Record 49 of Set 10 | taoudenni
# Processing Record 50 of Set 10 | vikhorevka
# Processing Record 1 of Set 11 | padang
# Processing Record 2 of Set 11 | upanema
# Processing Record 3 of Set 11 | yekaterinoslavka
# Processing Record 4 of Set 11 | nome
# Processing Record 5 of Set 11 | san severo
# Processing Record 6 of Set 11 | rawson
# Processing Record 7 of Set 11 | ondjiva
# Processing Record 8 of Set 11 | valleyview
# Processing Record 9 of Set 11 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 10 of Set 11 | tilichiki
# Processing Record 11 of Set 11 | dossor
# Processing Record 12 of Set 11 | harper
# Processing Record 13 of Set 11 | senneterre
# Processing Record 14 of Set 11 | iroquois falls
# Processing Record 15 of Set 11 | niteroi
# Processing Record 16 of Set 11 | leshukonskoye
# Processing Record 17 of Set 11 | akureyri
# Processing Record 18 of Set 11 | hambantota
# Processing Record 19 of Set 11 | soyaniquilpan
# Processing Record 20 of Set 11 | kifri
# Processing Record 21 of Set 11 | waipawa
# Processing Record 22 of Set 11 | muzhi
# Processing Record 23 of Set 11 | flin flon
# Processing Record 24 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 25 of Set 11 | qaqortoq
# Processing Record 26 of Set 11 | batouri
# Processing Record 27 of Set 11 | sumenep
# Processing Record 28 of Set 11 | port hawkesbury
# Processing Record 29 of Set 11 | dharchula
# Processing Record 30 of Set 11 | sterling
# Processing Record 31 of Set 11 | kantunilkin
# Processing Record 32 of Set 11 | bocaiuva
# Processing Record 33 of Set 11 | gambo
# Processing Record 34 of Set 11 | montrose
# Processing Record 35 of Set 11 | rocha
# Processing Record 36 of Set 11 | narsaq
# Processing Record 37 of Set 11 | punta alta
# Processing Record 38 of Set 11 | mabaruma
# Processing Record 39 of Set 11 | tyukalinsk
# Processing Record 40 of Set 11 | bella union
# Processing Record 41 of Set 11 | balabac
# Processing Record 42 of Set 11 | fairbanks
# Processing Record 43 of Set 11 | polazna
# Processing Record 44 of Set 11 | guerande
# Processing Record 45 of Set 11 | imeni stepana razina
# Processing Record 46 of Set 11 | esperance
# Processing Record 47 of Set 11 | dong hoi
# Processing Record 48 of Set 11 | natal
# Processing Record 49 of Set 11 | guerrero negro
# Processing Record 50 of Set 11 | togur
# Processing Record 1 of Set 12 | vao
# Processing Record 2 of Set 12 | los llanos de aridane
# Processing Record 3 of Set 12 | kadayanallur
# Processing Record 4 of Set 12 | jieshi
# Processing Record 5 of Set 12 | benguela
# Processing Record 6 of Set 12 | kieta
# Processing Record 7 of Set 12 | college
# Processing Record 8 of Set 12 | coquimbo
# Processing Record 9 of Set 12 | dalvik
# Processing Record 10 of Set 12 | naryan-mar
# Processing Record 11 of Set 12 | san martin
# Processing Record 12 of Set 12 | pundaguitan
# Processing Record 13 of Set 12 | ahumada
# City not found. Skipping...
# Processing Record 14 of Set 12 | otane
# Processing Record 15 of Set 12 | shache
# Processing Record 16 of Set 12 | shellbrook
# Processing Record 17 of Set 12 | porbandar
# Processing Record 18 of Set 12 | manado
# Processing Record 19 of Set 12 | tokat
# Processing Record 20 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 21 of Set 12 | sioux lookout
# Processing Record 22 of Set 12 | kathu
# Processing Record 23 of Set 12 | kochi
# Processing Record 24 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 25 of Set 12 | mason city
# Processing Record 26 of Set 12 | sena madureira
# Processing Record 27 of Set 12 | coihaique
# Processing Record 28 of Set 12 | haines junction
# Processing Record 29 of Set 12 | vanavara
# Processing Record 30 of Set 12 | wuda
# Processing Record 31 of Set 12 | saint-joseph
# Processing Record 32 of Set 12 | atessa
# Processing Record 33 of Set 12 | grand gaube
# Processing Record 34 of Set 12 | kaputa
# Processing Record 35 of Set 12 | griffith
# Processing Record 36 of Set 12 | cooma
# Processing Record 37 of Set 12 | cidreira
# Processing Record 38 of Set 12 | port hueneme
# Processing Record 39 of Set 12 | watertown
# Processing Record 40 of Set 12 | karamea
# City not found. Skipping...
# Processing Record 41 of Set 12 | richmond
# Processing Record 42 of Set 12 | jimo
# Processing Record 43 of Set 12 | dombarovskiy
# Processing Record 44 of Set 12 | araouane
# Processing Record 45 of Set 12 | dharmanagar
# Processing Record 46 of Set 12 | krasnyye baki
# Processing Record 47 of Set 12 | carahue
# Processing Record 48 of Set 12 | tabuk
# Processing Record 49 of Set 12 | grindavik
# Processing Record 50 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 1 of Set 13 | chapais
# Processing Record 2 of Set 13 | varhaug
# Processing Record 3 of Set 13 | petropavlovka
# Processing Record 4 of Set 13 | satitoa
# City not found. Skipping...
# Processing Record 5 of Set 13 | rorvik
# Processing Record 6 of Set 13 | sakakah
# Processing Record 7 of Set 13 | mitsamiouli
# Processing Record 8 of Set 13 | hagere hiywet
# Processing Record 9 of Set 13 | mazyr
# Processing Record 10 of Set 13 | ginda
# Processing Record 11 of Set 13 | ambilobe
# Processing Record 12 of Set 13 | newport
# Processing Record 13 of Set 13 | moranbah
# Processing Record 14 of Set 13 | xiongzhou
# Processing Record 15 of Set 13 | teguldet
# Processing Record 16 of Set 13 | dindigul
# Processing Record 17 of Set 13 | turkistan
# Processing Record 18 of Set 13 | sobolevo
# Processing Record 19 of Set 13 | moose jaw
# Processing Record 20 of Set 13 | sungaipenuh
# Processing Record 21 of Set 13 | penzance
# Processing Record 22 of Set 13 | lewistown
# Processing Record 23 of Set 13 | takoradi
# Processing Record 24 of Set 13 | idar
# Processing Record 25 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 13 | kapustin yar
# Processing Record 27 of Set 13 | la rochelle
# Processing Record 28 of Set 13 | gamba
# Processing Record 29 of Set 13 | buraydah
# Processing Record 30 of Set 13 | ozernovskiy
# Processing Record 31 of Set 13 | itabera
# Processing Record 32 of Set 13 | mao
# Processing Record 33 of Set 13 | soe
# Processing Record 34 of Set 13 | tura
# Processing Record 35 of Set 13 | yangambi
# Processing Record 36 of Set 13 | maidstone
# Processing Record 37 of Set 13 | ambon
# Processing Record 38 of Set 13 | kloulklubed
# Processing Record 39 of Set 13 | mushie
# Processing Record 40 of Set 13 | lapua
# Processing Record 41 of Set 13 | biryukove
# Processing Record 42 of Set 13 | bulaevo
# Processing Record 43 of Set 13 | port-gentil
# Processing Record 44 of Set 13 | trincomalee
# Processing Record 45 of Set 13 | sur
# Processing Record 46 of Set 13 | oistins
# Processing Record 47 of Set 13 | tarnogskiy gorodok
# Processing Record 48 of Set 13 | tongchuan
# Processing Record 49 of Set 13 | bosaso
# Processing Record 50 of Set 13 | vredendal
# Processing Record 1 of Set 14 | shingu
# Processing Record 2 of Set 14 | vilcun
# Processing Record 3 of Set 14 | bud
# Processing Record 4 of Set 14 | onega
# Processing Record 5 of Set 14 | sangin
# Processing Record 6 of Set 14 | verkh-usugli
# Processing Record 7 of Set 14 | fevik
# Processing Record 8 of Set 14 | xadani
# City not found. Skipping...
# Processing Record 9 of Set 14 | sergeyevka
# Processing Record 10 of Set 14 | wa
# City not found. Skipping...
# Processing Record 11 of Set 14 | moree
# Processing Record 12 of Set 14 | steamboat springs
# Processing Record 13 of Set 14 | nyrsko
# Processing Record 14 of Set 14 | ostuni
# Processing Record 15 of Set 14 | dera ismail khan
# Processing Record 16 of Set 14 | pozo colorado
# Processing Record 17 of Set 14 | pervomayskoye
# Processing Record 18 of Set 14 | nantucket
# Processing Record 19 of Set 14 | eston
# Processing Record 20 of Set 14 | quatre cocos
# Processing Record 21 of Set 14 | doctor arroyo
# Processing Record 22 of Set 14 | zhireken
# Processing Record 23 of Set 14 | formoso do araguaia
# City not found. Skipping...
# Processing Record 24 of Set 14 | alice springs
# Processing Record 25 of Set 14 | santa cruz de la palma
# Processing Record 26 of Set 14 | dubasari
# Processing Record 27 of Set 14 | shimoda
# Processing Record 28 of Set 14 | baoshan
# Processing Record 29 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 30 of Set 14 | london
# Processing Record 31 of Set 14 | nerchinskiy zavod
# Processing Record 32 of Set 14 | ende
# Processing Record 33 of Set 14 | yeniseysk
# Processing Record 34 of Set 14 | znamenskoye
# Processing Record 35 of Set 14 | peterhead
# Processing Record 36 of Set 14 | puro
# Processing Record 37 of Set 14 | minot
# Processing Record 38 of Set 14 | colesberg
# Processing Record 39 of Set 14 | maldonado
# Processing Record 40 of Set 14 | mangan
# Processing Record 41 of Set 14 | zlobin
# Processing Record 42 of Set 14 | funtua
# Processing Record 43 of Set 14 | timaru
# Processing Record 44 of Set 14 | pilar
# Processing Record 45 of Set 14 | sharan
# Processing Record 46 of Set 14 | aksu
# Processing Record 47 of Set 14 | sinop
# Processing Record 48 of Set 14 | adrar
# Processing Record 49 of Set 14 | kimbe
# Processing Record 50 of Set 14 | kargopol
# Processing Record 1 of Set 15 | faya
# Processing Record 2 of Set 15 | cairns
# Processing Record 3 of Set 15 | dudinka
# Processing Record 4 of Set 15 | kondratovo
# Processing Record 5 of Set 15 | punta de piedra
# Processing Record 6 of Set 15 | cuamba
# Processing Record 7 of Set 15 | kesan
# Processing Record 8 of Set 15 | puerto escondido
# Processing Record 9 of Set 15 | ormara
# Processing Record 10 of Set 15 | zapolyarnyy
# Processing Record 11 of Set 15 | miramar
# Processing Record 12 of Set 15 | henties bay
# Processing Record 13 of Set 15 | dzerzhinskoye
# Processing Record 14 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 15 of Set 15 | abancay
# Processing Record 16 of Set 15 | snasa
# Processing Record 17 of Set 15 | slave lake
# Processing Record 18 of Set 15 | honiara
# Processing Record 19 of Set 15 | srednekolymsk
# Processing Record 20 of Set 15 | camopi
# Processing Record 21 of Set 15 | pamanukan
# Processing Record 22 of Set 15 | taft
# Processing Record 23 of Set 15 | udachnyy
# Processing Record 24 of Set 15 | olinda
# Processing Record 25 of Set 15 | vizinga
# Processing Record 26 of Set 15 | college place
# Processing Record 27 of Set 15 | copiapo
# Processing Record 28 of Set 15 | kendari
# Processing Record 29 of Set 15 | mackenzie
# Processing Record 30 of Set 15 | krasnopavlivka
# Processing Record 31 of Set 15 | evensk
# Processing Record 32 of Set 15 | biltine
# Processing Record 33 of Set 15 | kenitra
# Processing Record 34 of Set 15 | rayagada
# Processing Record 35 of Set 15 | san cristobal
# Processing Record 36 of Set 15 | ujkigyos
# Processing Record 37 of Set 15 | berdigestyakh
# Processing Record 38 of Set 15 | bennington
# Processing Record 39 of Set 15 | leh
# Processing Record 40 of Set 15 | rio gallegos
# Processing Record 41 of Set 15 | anadyr
# Processing Record 42 of Set 15 | estacion coahuila
# Processing Record 43 of Set 15 | pedernales
# Processing Record 44 of Set 15 | dulce nombre de culmi
# Processing Record 45 of Set 15 | riyadh
# Processing Record 46 of Set 15 | keetmanshoop
# Processing Record 47 of Set 15 | nguiu
# City not found. Skipping...
# Processing Record 48 of Set 15 | ghioroiu
# Processing Record 49 of Set 15 | tobermory
# Processing Record 50 of Set 15 | sao jose da coroa grande
# Processing Record 1 of Set 16 | wladyslawowo
# Processing Record 2 of Set 16 | general teran
# Processing Record 3 of Set 16 | sijunjung
# Processing Record 4 of Set 16 | florianopolis
# Processing Record 5 of Set 16 | goure
# Processing Record 6 of Set 16 | san andres
# Processing Record 7 of Set 16 | sao paulo de olivenca
# Processing Record 8 of Set 16 | mount vernon
# Processing Record 9 of Set 16 | richards bay
# Processing Record 10 of Set 16 | baruun-urt
# Processing Record 11 of Set 16 | lodwar
# Processing Record 12 of Set 16 | hirado
# Processing Record 13 of Set 16 | sao felix do xingu
# Processing Record 14 of Set 16 | friendswood
# Processing Record 15 of Set 16 | praia da vitoria
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
new_column_order = ["City","Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]
city_data_df = city_data_df[new_column_order]
city_data_df["Lat"] = round(city_data_df["Lat"],2)
city_data_df["Lng"] = round(city_data_df["Lng"],2)
city_data_df.head(10)
# Out:
#           City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0    Sistranda      NO  63.73    8.83    275.32        85         100
# 1      Mataura      NZ -46.19  168.86    283.97        91         100
# 2  East London      ZA -33.02   27.91    299.89        80           0
# 3      Rikitea      PF -23.12 -134.97    299.22        71          48
# 4       Atuona      PF  -9.80 -139.03    298.24        79          10
# 5        Kapaa      US  22.08 -159.32    293.14        97          75
# 6        Vardo      NO  70.37   31.11    269.89        71          37
# 7       Hobart      AU -42.88  147.33    287.07        74          92
# 8     Pochutla      MX  15.74  -96.47    302.05        45          21
# 9    Upernavik      GL  72.79  -56.15    252.69        98         100
#
#    Wind Speed Weather Description
# 0        6.12       moderate rain
# 1        1.41     overcast clouds
# 2        7.30           clear sky
# 3        7.10          light rain
# 4        6.12          light rain
# 5        3.09       broken clouds
# 6        5.98    scattered clouds
# 7        3.60     overcast clouds
# 8        1.48          few clouds
# 9        6.21     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
